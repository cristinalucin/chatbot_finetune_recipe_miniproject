# %%
import pandas as pd, numpy as np, re, os
from urllib.request import urlopen
from urllib.request import Request
from urllib.parse import urlparse
from bs4 import BeautifulSoup
import requests
from urllib.parse import urljoin
import html5lib
import time
import random
from io import BytesIO
import zlib
import gzip

# %%
# def get_page(url):
#     """Scrapes a URL and returns the HTML source.
    
#     Args:
#         url (string): Fully qualified URL of a page.
    
#     Returns:
#         soup (string): HTML source of scraped page.
#     """

#     response = urllib.request.urlopen(urllib.request.Request(url, 
#                                                              headers={'User-Agent': 'Mozilla'}))
#     soup = BeautifulSoup(response, 
#                          'html.parser', 
#                          from_encoding=response.info().get_param('charset'))
    
#     return soup

# %%
page = "https://www.socom.mil/SOF-ATL/"

# %%
# No robots.txt page present (SOCOM.MIL has one though)
robots = get_page("https://www.socom.mil/SOF-ATL/robots.txt")
robots

# %%
def fetch_page(url):
    response = requests.get(url)
    if response.status_code == 200:
        response.encoding = response.apparent_encoding  # Ensures correct encoding interpretation
        return response.text
    else:
        return None

def parse_links(html, base_url):
    try:
        soup = BeautifulSoup(html, 'html5lib')  # using html5lib as the parser
        for link in soup.find_all('a', href=True):
            full_url = urljoin(base_url, link['href'])
            if full_url.startswith(base_url):  # Filtering external links
                yield full_url
    except Exception as e:
        print(f"Error parsing HTML: {e}")


def crawl_website(base_url):
    visited = set()
    pages_to_visit = {base_url}
    
    while pages_to_visit:
        current_page = pages_to_visit.pop()
        if current_page not in visited:
            visited.add(current_page)
            html_content = fetch_page(current_page)
            if html_content:
                for url in parse_links(html_content, base_url):
                    pages_to_visit.add(url)
            print(f"Visited: {current_page}")
        time.sleep(random.uniform(0.5,2.0)) # Sleep for random time in between 0.5 and 2 seconds
    return visited

# %%
# Scrape the page

base_url = 'https://www.socom.mil/SOF-ATL/'
all_pages = crawl_website(base_url)
# Out:
# Visited: https://www.socom.mil/SOF-ATL/
# Visited: https://www.socom.mil/SOF-ATL/Pages/cto.aspx
# Visited: https://www.socom.mil/SOF-ATL/Pages/SOF_ATL_Lines_of_Effort.aspx
# Visited: https://www.socom.mil/SOF-ATL/Pages/SOF-Hard-Problems.aspx
# Visited: https://www.socom.mil/SOF-ATL/SOFHardProblemsDocumentLibrary/USSOCOM%20ST%20Mission%20Assured%20Communications%20-%20MAC%20MegaTalker-Apr23.docx
# Visited: https://www.socom.mil/SOF-ATL/Pages/eSOF-main.aspx
# Visited: https://www.socom.mil/SOF-ATL/Pages/Defense-Industrial-Base-Cybersecurity.aspx
# Visited: https://www.socom.mil/SOF-ATL/Pages/programs.aspx
# Visited: https://www.socom.mil/SOF-ATL/PublishingImages/ViperStrike.jpg
# Visited: https://www.socom.mil/SOF-ATL/Pages/eSOF-submit-your-idea-form-instruct.aspx
# Visited: https://www.socom.mil/SOF-ATL/Pages/eSOF-process.aspx
# Visited: https://www.socom.mil/SOF-ATL/SOFHardProblemsDocumentLibrary/USSOCOM%20ST%20Signature%20Management%20-%20SIGMAN%20MegaTalker-Apr23.docx
# Visited: https://www.socom.mil/SOF-ATL/Pages/eSOF_cap_of_interest.aspx
# Visited: https://www.socom.mil/SOF-ATL/Pages/Acquisition-Authority.aspx
# Visited: https://www.socom.mil/SOF-ATL/Pages/BusinessOpportunitiesOffice.aspx
# Visited: https://www.socom.mil/SOF-ATL/SOF%20ATL%20Recruitment%20Video/SOF_ATL%20Recruitment%20w%20Blur%20compressed%20V1.mp4
# Visited: https://www.socom.mil/SOF-ATL/Pages/Capabilities.aspx
# Visited: https://www.socom.mil/SOF-ATL/Pages/contracting.aspx
# Visited: https://www.socom.mil/SOF-ATL/Pages/eSOF-before-you-submit.aspx
# Visited: https://www.socom.mil/SOF-ATL/Pages/SOF%20Week.aspx
# Visited: https://www.socom.mil/SOF-ATL/Pages/eSOF-faqs.aspx
# Visited: https://www.socom.mil/SOF-ATL/Pages/OMBUDSMAN.aspx
# Visited: https://www.socom.mil/SOF-ATL/Pages/sbir-P1.aspx
# Visited: https://www.socom.mil/SOF-ATL/PublishingImages/TFCforMAAWS.jpg
# Visited: https://www.socom.mil/SOF-ATL/Pages/advanced-mfg.aspx
# Visited: https://www.socom.mil/SOF-ATL/Pages/Doing-Business-Contact-Info.aspx
# Visited: https://www.socom.mil/SOF-ATL/Pages/sv.aspx
# Visited: https://www.socom.mil/SOF-ATL/SOFATL%20Outreach%20Events/SOF%20ATL%20Outreach%20Events.pdf
# Visited: https://www.socom.mil/SOF-ATL/SBIR-Docs/Phase1/Phase%20I%20Cost%20Volume%20Template.xlsx
# Visited: https://www.socom.mil/SOF-ATL/Major%20acquisition%20Library/Major%20acquisition%20listing.pdf
# Visited: https://www.socom.mil/SOF-ATL/Pages/baa.aspx
# Visited: https://www.socom.mil/SOF-ATL/Pages/Join-Us.aspx
# Visited: https://www.socom.mil/SOF-ATL/Pages/SV.aspx
# Visited: https://www.socom.mil/SOF-ATL/SOFHardProblemsDocumentLibrary/USSOCOM%20ST%20SOF%20Small%20Unit%20Dominance%20-SOFSUD%20MegaTalker-Apr23.docx
# Visited: https://www.socom.mil/SOF-ATL/Pages/hrpo.aspx
# Visited: https://www.socom.mil/SOF-ATL/Pages/small-business.aspx
# Visited: https://www.socom.mil/SOF-ATL/Lists/HRPORegPolProcLinks
# Visited: https://www.socom.mil/SOF-ATL/SBIR-Docs/Phase1/CDRL5_Atch1-Contract-Officer.pdf
# Visited: https://www.socom.mil/SOF-ATL/Lists/HRPORefLinks
# Visited: https://www.socom.mil/SOF-ATL/Pages/BAAST2020-Sub-Form.aspx
# Visited: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/GuideCareAndUseLaboratoryAnimals.pdf
# Visited: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/2020-AVMA-GuidelinesEuthanasiaAnimals.pdf
# Visited: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/2022 DoD-Standard-Protocol-Format-final.pdf
# Visited: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/SIGNED - DHA-MSR 6025.02 - Animals.pdf
# Visited: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/VRO_Animal_Res_Rev_June21_blk(PDF Fillable).pdf
# Visited: https://www.socom.mil/SOF-ATL/Pages/SOF-ATL-Apprentice-Program.aspx
# Visited: https://www.socom.mil/SOF-ATL/Lists/HRPOGovLinks
# Visited: https://www.socom.mil/SOF-ATL/Lists/HRPOContacts
# Visited: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/VRO_Animal_Research_Rev_June21_blk(Word).docx
# Visited: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/VRO_Animal_Research_Review_V1.2_Nov_18.docx
# Visited: https://www.socom.mil/SOF-ATL/Pages/technical-experimentation.aspx
# Visited: https://www.socom.mil/SOF-ATL/Pages/icd.aspx
# Visited: https://www.socom.mil/SOF-ATL/Pages/Services%20Industry%20partner%20info.aspx
# Visited: https://www.socom.mil/SOF-ATL/Pages/Apprentice-Resume-Submission.aspx
# Visited: https://www.socom.mil/SOF-ATL/PublishingImages/2024%20Tri-Fold%20Services.pdf
# Visited: https://www.socom.mil/SOF-ATL/Pages/sbir.aspx
# Visited: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/201903_DoDI_3216_01_UseOfAnimalsInDoD.pdf
# Visited: https://www.socom.mil/SOF-ATL/HRPODocumentLibrary
# Visited: https://www.socom.mil/SOF-ATL/Lists/VROReferences
# Visited: https://www.socom.mil/SOF-ATL/SBIR-Docs/Phase1/PHI_CDRL_A001_to_A005_Template.docx
# Visited: https://www.socom.mil/SOF-ATL/HRPODocumentLibrary/SOCOM  submissions file naming 7 July.docx
# Visited: https://www.socom.mil/SOF-ATL/Lists/VROContacts
# Visited: https://www.socom.mil/SOF-ATL/Areas%20of%20Interest%20Descriptions/SOF%20ATL%20Areas%20of%20Interest%20Descriptions.pdf
# Visited: https://www.socom.mil/SOF-ATL/SBIR-Docs/Phase1/Atch3_Section_K.pdf
# Visited: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/2019 USDA AWA_AWR.pdf
# Visited: https://www.socom.mil/SOF-ATL/Documents/TE-AAR-Survey.docx
# Visited: https://www.socom.mil/SOF-ATL/SBIR-Docs/Phase1/CDRL5_Atch-1_SOFWERX.pdf
# Visited: https://www.socom.mil/SOF-ATL/HRPODocumentLibrary/HRPO_Protocol_Submission_Form_v 8.0 9JUNE2020.docx
# Visited: https://www.socom.mil/SOF-ATL/Pages/Services%20Req%20Activ%20spon.aspx
# Visited: https://www.socom.mil/SOF-ATL/Pages/Org_Chart.aspx
# Visited: https://www.socom.mil/SOF-ATL/Documents/TENTATIVE%20ACQUISITION%20FORECAST%20FY24-FY27_AUG2023.pdf
# Visited: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/DoD Animal Use Protocol Format.doc
# Visited: https://www.socom.mil/SOF-ATL/HRPODocumentLibrary/USSOCOM Human Research Determination for Researchers v1.2.pdf
# Visited: https://www.socom.mil/SOF-ATL/VRODocumentLibrary
# Visited: https://www.socom.mil/SOF-ATL/Pages/FAQ.aspx
# Visited: https://www.socom.mil/SOF-ATL/#experimentation
# Visited: https://www.socom.mil/SOF-ATL/#whattoexpect
# Visited: https://www.socom.mil/SOF-ATL/Pages/technicalexpsurvey.aspx
# Visited: https://www.socom.mil/SOF-ATL/#general
# Visited: https://www.socom.mil/SOF-ATL/#RFLaserUAS
# Visited: https://www.socom.mil/SOF-ATL/#teover
# Visited: https://www.socom.mil/SOF-ATL/Pages/FAQ.aspx#Top
# Visited: https://www.socom.mil/SOF-ATL/#participationprocess
# Visited: https://www.socom.mil/SOF-ATL/#nowwhat

# %%
# Adding function to save the content from URLs

def fetch_page(url):
    response = requests.get(url)
    if response.status_code == 200:
        response.encoding = response.apparent_encoding  # Ensures correct encoding interpretation
        return response.text
    else:
        return None

def parse_links(html, base_url):
    try:
        soup = BeautifulSoup(html, 'lxml')
        for link in soup.find_all('a', href=True):
            full_url = urljoin(base_url, link['href'])
            if full_url.startswith(base_url):  # Filtering external links
                yield full_url
    except Exception as e:
        print(f"Error parsing HTML: {e}")

def save_content(html, url, base_dir="./website_data"):
    filename = url.replace("https://", "").replace("http://", "").replace("/", "_") + ".html"
    filepath = os.path.join(base_dir, filename)
    os.makedirs(base_dir, exist_ok=True)
    with open(filepath, 'w', encoding='utf-8') as f:
        f.write(html)

def crawl_website(base_url):
    visited = set()
    pages_to_visit = {base_url}
    
    while pages_to_visit:
        current_page = pages_to_visit.pop()
        if current_page not in visited:
            visited.add(current_page)
            html_content = fetch_page(current_page)
            if html_content:
                save_content(html_content, current_page)  # Save page content to file
                for url in parse_links(html_content, base_url):
                    pages_to_visit.add(url)
                print(f"Visited and saved: {current_page}")
            # Sleep between requests
            time.sleep(random.uniform(0.5, 2.0))  # Sleep for a random time between 0.5 and 2 seconds
    return visited

# %%
# Try again to scrape

base_url = 'https://www.socom.mil/SOF-ATL/'
all_pages = crawl_website(base_url)
# Out:
# Visited and saved: https://www.socom.mil/SOF-ATL/
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/cto.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/SOF_ATL_Lines_of_Effort.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/SOF-Hard-Problems.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/SOFHardProblemsDocumentLibrary/USSOCOM%20ST%20Mission%20Assured%20Communications%20-%20MAC%20MegaTalker-Apr23.docx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/eSOF-main.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/Defense-Industrial-Base-Cybersecurity.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/programs.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/eSOF-submit-your-idea-form-instruct.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/eSOF-process.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/SOFHardProblemsDocumentLibrary/USSOCOM%20ST%20Signature%20Management%20-%20SIGMAN%20MegaTalker-Apr23.docx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/Acquisition-Authority.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/BusinessOpportunitiesOffice.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/SOF%20ATL%20Recruitment%20Video/SOF_ATL%20Recruitment%20w%20Blur%20compressed%20V1.mp4
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/Capabilities.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/contracting.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/eSOF-before-you-submit.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/SOF%20Week.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/eSOF-faqs.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/OMBUDSMAN.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/sbir-P1.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/advanced-mfg.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/Doing-Business-Contact-Info.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/sv.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/SOFATL%20Outreach%20Events/SOF%20ATL%20Outreach%20Events.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/SBIR-Docs/Phase1/Phase%20I%20Cost%20Volume%20Template.xlsx
# Visited and saved: https://www.socom.mil/SOF-ATL/Major%20acquisition%20Library/Major%20acquisition%20listing.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/baa.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/Join-Us.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/SV.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/SOFHardProblemsDocumentLibrary/USSOCOM%20ST%20SOF%20Small%20Unit%20Dominance%20-SOFSUD%20MegaTalker-Apr23.docx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/hrpo.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/small-business.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/SBIR-Docs/Phase1/CDRL5_Atch1-Contract-Officer.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/BAAST2020-Sub-Form.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/GuideCareAndUseLaboratoryAnimals.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/2020-AVMA-GuidelinesEuthanasiaAnimals.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/2022 DoD-Standard-Protocol-Format-final.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/SIGNED - DHA-MSR 6025.02 - Animals.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/VRO_Animal_Res_Rev_June21_blk(PDF Fillable).pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/SOF-ATL-Apprentice-Program.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/VRO_Animal_Research_Rev_June21_blk(Word).docx
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/VRO_Animal_Research_Review_V1.2_Nov_18.docx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/technical-experimentation.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/icd.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/Services%20Industry%20partner%20info.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/Apprentice-Resume-Submission.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/PublishingImages/2024%20Tri-Fold%20Services.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/sbir.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/201903_DoDI_3216_01_UseOfAnimalsInDoD.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/SBIR-Docs/Phase1/PHI_CDRL_A001_to_A005_Template.docx
# Visited and saved: https://www.socom.mil/SOF-ATL/HRPODocumentLibrary/SOCOM  submissions file naming 7 July.docx
# Visited and saved: https://www.socom.mil/SOF-ATL/Areas%20of%20Interest%20Descriptions/SOF%20ATL%20Areas%20of%20Interest%20Descriptions.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/SBIR-Docs/Phase1/Atch3_Section_K.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/2019 USDA AWA_AWR.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/Documents/TE-AAR-Survey.docx
# Visited and saved: https://www.socom.mil/SOF-ATL/SBIR-Docs/Phase1/CDRL5_Atch-1_SOFWERX.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/HRPODocumentLibrary/HRPO_Protocol_Submission_Form_v 8.0 9JUNE2020.docx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/Services%20Req%20Activ%20spon.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/Org_Chart.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Documents/TENTATIVE%20ACQUISITION%20FORECAST%20FY24-FY27_AUG2023.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/DoD Animal Use Protocol Format.doc
# Visited and saved: https://www.socom.mil/SOF-ATL/HRPODocumentLibrary/USSOCOM Human Research Determination for Researchers v1.2.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/FAQ.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/#experimentation
# Visited and saved: https://www.socom.mil/SOF-ATL/#whattoexpect
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/technicalexpsurvey.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/#general
# Visited and saved: https://www.socom.mil/SOF-ATL/#RFLaserUAS
# Visited and saved: https://www.socom.mil/SOF-ATL/#teover
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/FAQ.aspx#Top
# Visited and saved: https://www.socom.mil/SOF-ATL/#participationprocess
# Visited and saved: https://www.socom.mil/SOF-ATL/#nowwhat

# %%
# Trying again

def fetch_page(url):
    headers = {
        'Accept-Encoding': 'gzip, deflate',  # indicates that your client can accept compressed content
    }
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        response.encoding = response.apparent_encoding
        if response.headers.get('content-encoding') == 'gzip':
            from io import BytesIO
            import gzip
            buffer = BytesIO(response.content)
            with gzip.open(buffer, 'rt', encoding=response.apparent_encoding) as f:
                return f.read()
        return response.text
    else:
        return None



def parse_links(html, base_url):
    try:
        soup = BeautifulSoup(html, 'lxml')
        for link in soup.find_all('a', href=True):
            full_url = urljoin(base_url, link['href'])
            if full_url.startswith(base_url):
                yield full_url
    except Exception as e:
        print(f"Error parsing HTML: {e}")


def save_content(html, url, base_dir="./website_data"):
    filename = url.replace("https://", "").replace("http://", "").replace("/", "_") + ".html"
    filepath = os.path.join(base_dir, filename)
    os.makedirs(base_dir, exist_ok=True)
    with open(filepath, 'w', encoding='utf-8') as f:
        f.write(html)

def crawl_website(base_url):
    visited = set()
    pages_to_visit = {base_url}
    
    while pages_to_visit:
        current_page = pages_to_visit.pop()
        if current_page not in visited:
            visited.add(current_page)
            html_content = fetch_page(current_page)
            if html_content:
                save_content(html_content, current_page)
                for url in parse_links(html_content, base_url):
                    pages_to_visit.add(url)
                print(f"Visited and saved: {current_page}")
            time.sleep(random.uniform(0.5, 2.0))
    return visited

# %%
# Try again...

base_url = 'https://www.socom.mil/SOF-ATL/'
all_pages = crawl_website(base_url)
# Out:
# Visited and saved: https://www.socom.mil/SOF-ATL/
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/cto.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/SOF_ATL_Lines_of_Effort.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/SOF-Hard-Problems.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/SOFHardProblemsDocumentLibrary/USSOCOM%20ST%20Mission%20Assured%20Communications%20-%20MAC%20MegaTalker-Apr23.docx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/eSOF-main.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/Defense-Industrial-Base-Cybersecurity.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/programs.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/eSOF-submit-your-idea-form-instruct.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/eSOF-process.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/SOFHardProblemsDocumentLibrary/USSOCOM%20ST%20Signature%20Management%20-%20SIGMAN%20MegaTalker-Apr23.docx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/Acquisition-Authority.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/BusinessOpportunitiesOffice.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/SOF%20ATL%20Recruitment%20Video/SOF_ATL%20Recruitment%20w%20Blur%20compressed%20V1.mp4
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/Capabilities.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/contracting.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/eSOF-before-you-submit.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/SOF%20Week.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/eSOF-faqs.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/OMBUDSMAN.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/sbir-P1.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/advanced-mfg.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/Doing-Business-Contact-Info.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/sv.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/SOFATL%20Outreach%20Events/SOF%20ATL%20Outreach%20Events.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/SBIR-Docs/Phase1/Phase%20I%20Cost%20Volume%20Template.xlsx
# Visited and saved: https://www.socom.mil/SOF-ATL/Major%20acquisition%20Library/Major%20acquisition%20listing.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/baa.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/Join-Us.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/SV.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/SOFHardProblemsDocumentLibrary/USSOCOM%20ST%20SOF%20Small%20Unit%20Dominance%20-SOFSUD%20MegaTalker-Apr23.docx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/hrpo.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/small-business.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/SBIR-Docs/Phase1/CDRL5_Atch1-Contract-Officer.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/BAAST2020-Sub-Form.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/GuideCareAndUseLaboratoryAnimals.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/2020-AVMA-GuidelinesEuthanasiaAnimals.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/2022 DoD-Standard-Protocol-Format-final.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/SIGNED - DHA-MSR 6025.02 - Animals.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/VRO_Animal_Res_Rev_June21_blk(PDF Fillable).pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/SOF-ATL-Apprentice-Program.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/VRO_Animal_Research_Rev_June21_blk(Word).docx
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/VRO_Animal_Research_Review_V1.2_Nov_18.docx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/technical-experimentation.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/icd.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/Services%20Industry%20partner%20info.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/Apprentice-Resume-Submission.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/PublishingImages/2024%20Tri-Fold%20Services.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/sbir.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/201903_DoDI_3216_01_UseOfAnimalsInDoD.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/SBIR-Docs/Phase1/PHI_CDRL_A001_to_A005_Template.docx
# Visited and saved: https://www.socom.mil/SOF-ATL/HRPODocumentLibrary/SOCOM  submissions file naming 7 July.docx
# Visited and saved: https://www.socom.mil/SOF-ATL/Areas%20of%20Interest%20Descriptions/SOF%20ATL%20Areas%20of%20Interest%20Descriptions.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/SBIR-Docs/Phase1/Atch3_Section_K.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/2019 USDA AWA_AWR.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/Documents/TE-AAR-Survey.docx
# Visited and saved: https://www.socom.mil/SOF-ATL/SBIR-Docs/Phase1/CDRL5_Atch-1_SOFWERX.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/HRPODocumentLibrary/HRPO_Protocol_Submission_Form_v 8.0 9JUNE2020.docx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/Services%20Req%20Activ%20spon.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/Org_Chart.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Documents/TENTATIVE%20ACQUISITION%20FORECAST%20FY24-FY27_AUG2023.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/DoD Animal Use Protocol Format.doc
# Visited and saved: https://www.socom.mil/SOF-ATL/HRPODocumentLibrary/USSOCOM Human Research Determination for Researchers v1.2.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/FAQ.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/#experimentation
# Visited and saved: https://www.socom.mil/SOF-ATL/#whattoexpect
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/technicalexpsurvey.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/#general
# Visited and saved: https://www.socom.mil/SOF-ATL/#RFLaserUAS
# Visited and saved: https://www.socom.mil/SOF-ATL/#teover
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/FAQ.aspx#Top
# Visited and saved: https://www.socom.mil/SOF-ATL/#participationprocess
# Visited and saved: https://www.socom.mil/SOF-ATL/#nowwhat

# %% [markdown]
# ### Trying to adjust again because we returned a ton of white space and a few uncoded characters

# %%
def fetch_page(url):
    headers = {'Accept-Encoding': 'gzip, deflate'}  # Handles gzip and deflate encodings
    try:
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            # Handling potential content encoding
            if 'gzip' in response.headers.get('Content-Encoding', ''):
                # Use gzip module to decode
                buffer = BytesIO(response.content)
                with gzip.open(buffer, 'rt', encoding='utf-8') as f:
                    return f.read()
            elif 'deflate' in response.headers.get('Content-Encoding', ''):
                # Use zlib to decode deflate encoding
                try:
                    return zlib.decompress(response.content).decode('utf-8')
                except zlib.error:
                    return zlib.decompress(response.content, -zlib.MAX_WBITS).decode('utf-8')
            else:
                # No encoding, or encoding is handled by requests automatically
                return response.text
        else:
            print(f"Failed to fetch {url} with status code: {response.status_code}")
    except requests.RequestException as e:
        print(f"Request failed for {url}: {e}")
    return None

def parse_links(html, base_url):
    try:
        soup = BeautifulSoup(html, 'lxml')
        for link in soup.find_all('a', href=True):
            full_url = urljoin(base_url, link['href'])
            if full_url.startswith(base_url) and full_url not in visited:
                yield full_url
    except Exception as e:
        print(f"Error parsing HTML for {base_url}: {e}")

def save_content(html, url, base_dir="./website_data"):
    filename = url.replace("https://", "").replace("http://", "").replace("/", "_") + ".html"
    filepath = os.path.join(base_dir, filename)
    os.makedirs(base_dir, exist_ok=True)
    try:
        with open(filepath, 'w', encoding='utf-8') as f:
            f.write(html)
    except Exception as e:
        print(f"Failed to write {filepath}: {e}")

def crawl_website(base_url):
    global visited
    visited = set()
    pages_to_visit = {base_url}
    
    while pages_to_visit:
        current_page = pages_to_visit.pop()
        if current_page not in visited:
            visited.add(current_page)
            html_content = fetch_page(current_page)
            if html_content:
                save_content(html_content, current_page)
                for url in parse_links(html_content, base_url):
                    pages_to_visit.add(url)
                print(f"Visited and saved: {current_page}")
            time.sleep(random.uniform(0.5, 2.0))
    return visited

# %%
# Try again after modifying script to handle content encoding

base_url = 'https://www.socom.mil/SOF-ATL/'
all_pages = crawl_website(base_url)
# Out:
# Visited and saved: https://www.socom.mil/SOF-ATL/
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/cto.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/SOF_ATL_Lines_of_Effort.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/SOF-Hard-Problems.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/SOFHardProblemsDocumentLibrary/USSOCOM%20ST%20Mission%20Assured%20Communications%20-%20MAC%20MegaTalker-Apr23.docx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/eSOF-main.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/Defense-Industrial-Base-Cybersecurity.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/programs.aspx
# Failed to fetch https://www.socom.mil/SOF-ATL/PublishingImages/ViperStrike.jpg with status code: 404
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/eSOF-submit-your-idea-form-instruct.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/eSOF-process.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/SOFHardProblemsDocumentLibrary/USSOCOM%20ST%20Signature%20Management%20-%20SIGMAN%20MegaTalker-Apr23.docx
# Failed to fetch https://www.socom.mil/SOF-ATL/Pages/eSOF_cap_of_interest.aspx with status code: 404
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/Acquisition-Authority.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/BusinessOpportunitiesOffice.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/SOF%20ATL%20Recruitment%20Video/SOF_ATL%20Recruitment%20w%20Blur%20compressed%20V1.mp4
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/Capabilities.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/contracting.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/eSOF-before-you-submit.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/SOF%20Week.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/eSOF-faqs.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/OMBUDSMAN.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/sbir-P1.aspx
# Failed to fetch https://www.socom.mil/SOF-ATL/PublishingImages/TFCforMAAWS.jpg with status code: 404
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/advanced-mfg.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/Org_Chart.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/Doing-Business-Contact-Info.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/sv.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/technical-experimentation.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/SOFATL%20Outreach%20Events/SOF%20ATL%20Outreach%20Events.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/SBIR-Docs/Phase1/Phase%20I%20Cost%20Volume%20Template.xlsx
# Visited and saved: https://www.socom.mil/SOF-ATL/Major%20acquisition%20Library/Major%20acquisition%20listing.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/baa.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/Join-Us.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/icd.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/Services%20Industry%20partner%20info.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/FAQ.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/#experimentation
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/SV.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/PublishingImages/2024%20Tri-Fold%20Services.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/SOFHardProblemsDocumentLibrary/USSOCOM%20ST%20SOF%20Small%20Unit%20Dominance%20-SOFSUD%20MegaTalker-Apr23.docx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/sbir.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/hrpo.aspx
# Failed to fetch https://www.socom.mil/SOF-ATL/HRPODocumentLibrary with status code: 401
# Failed to fetch https://www.socom.mil/SOF-ATL/Lists/VROReferences with status code: 401
# Visited and saved: https://www.socom.mil/SOF-ATL/SBIR-Docs/Phase1/PHI_CDRL_A001_to_A005_Template.docx
# Visited and saved: https://www.socom.mil/SOF-ATL/#teover
# Visited and saved: https://www.socom.mil/SOF-ATL/HRPODocumentLibrary/SOCOM  submissions file naming 7 July.docx
# Failed to fetch https://www.socom.mil/SOF-ATL/Lists/VROContacts with status code: 401
# Visited and saved: https://www.socom.mil/SOF-ATL/SBIR-Docs/Phase1/Atch3_Section_K.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/FAQ.aspx#Top
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/2019 USDA AWA_AWR.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/Documents/TE-AAR-Survey.docx
# Visited and saved: https://www.socom.mil/SOF-ATL/SBIR-Docs/Phase1/CDRL5_Atch-1_SOFWERX.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/#participationprocess
# Visited and saved: https://www.socom.mil/SOF-ATL/HRPODocumentLibrary/HRPO_Protocol_Submission_Form_v 8.0 9JUNE2020.docx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/Services%20Req%20Activ%20spon.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/#nowwhat
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/DoD Animal Use Protocol Format.doc
# Visited and saved: https://www.socom.mil/SOF-ATL/HRPODocumentLibrary/USSOCOM Human Research Determination for Researchers v1.2.pdf
# Failed to fetch https://www.socom.mil/SOF-ATL/VRODocumentLibrary with status code: 401
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/small-business.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/#whattoexpect
# Failed to fetch https://www.socom.mil/SOF-ATL/Lists/HRPORegPolProcLinks with status code: 401
# Visited and saved: https://www.socom.mil/SOF-ATL/SBIR-Docs/Phase1/CDRL5_Atch1-Contract-Officer.pdf
# Failed to fetch https://www.socom.mil/SOF-ATL/Lists/HRPORefLinks with status code: 401
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/BAAST2020-Sub-Form.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/GuideCareAndUseLaboratoryAnimals.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/2020-AVMA-GuidelinesEuthanasiaAnimals.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/2022 DoD-Standard-Protocol-Format-final.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/technicalexpsurvey.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/#general
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/SIGNED - DHA-MSR 6025.02 - Animals.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/VRO_Animal_Res_Rev_June21_blk(PDF Fillable).pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/#RFLaserUAS
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/SOF-ATL-Apprentice-Program.aspx
# Failed to fetch https://www.socom.mil/SOF-ATL/Lists/HRPOGovLinks with status code: 401
# Failed to fetch https://www.socom.mil/SOF-ATL/Lists/HRPOContacts with status code: 401
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/VRO_Animal_Research_Rev_June21_blk(Word).docx
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/VRO_Animal_Research_Review_V1.2_Nov_18.docx
# Visited and saved: https://www.socom.mil/SOF-ATL/Pages/Apprentice-Resume-Submission.aspx
# Visited and saved: https://www.socom.mil/SOF-ATL/VRODocumentLibrary/201903_DoDI_3216_01_UseOfAnimalsInDoD.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/Areas%20of%20Interest%20Descriptions/SOF%20ATL%20Areas%20of%20Interest%20Descriptions.pdf
# Visited and saved: https://www.socom.mil/SOF-ATL/Documents/TENTATIVE%20ACQUISITION%20FORECAST%20FY24-FY27_AUG2023.pdf
